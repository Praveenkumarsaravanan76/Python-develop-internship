# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/internships/Analyse data/Data")
print("First 5 rows:")
print(df.head())
print("\nData Summary:")
print(df.describe())
average_rent = df['Rent'].mean()
print(f"\nAverage Rent: ₹{average_rent:.2f}")
plt.figure(figsize=(8, 5))
df['Location'].value_counts().plot(kind='bar', color='skyblue')
plt.title("Number of Properties by Location")
plt.xlabel("Location")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
plt.figure(figsize=(8, 5))
plt.scatter(df['Size'], df['Rent'], color='green', alpha=0.6)
plt.title('House Size vs Rent')
plt.xlabel('Size (sqft)')
plt.ylabel('Rent (₹)')
plt.grid(True)
plt.tight_layout()
plt.show()
plt.figure(figsize=(6, 4))
correlation = df[['Size', 'Bedroom', 'Rent']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()
# Out:
# First 5 rows:
#    Size  Bedroom   Location   Rent
# 0  1140        3    Kolkata  27567
# 1  1551        3     Mumbai  32566
# 2  1706        3      Delhi  37271
# 3  1785        4  Hyderabad  41039
# 4  1035        4     Mumbai  24556
#
# Data Summary:
#               Size     Bedroom          Rent
# count   100.000000  100.000000    100.000000
# mean   1163.420000    2.630000  27871.850000
# std     357.610001    1.069834   9009.546203
# min     605.000000    1.000000  11853.000000
# 25%     843.750000    2.000000  20324.000000
# 50%    1157.500000    3.000000  27918.500000
# 75%    1437.250000    4.000000  34216.500000
# max    1853.000000    4.000000  48287.000000
#
# Average Rent: ₹27871.85
